# %% [markdown]
# # **A Web-based Tool for Automatic Discovery and Mapping of OPERA Surface Displacement (DISP-S1) product**

# %% [markdown]
# By using this tool, you can search, download, and map **30-meter** **[OPERA Surface Displacement (DISP-S1) products](https://www.earthdata.nasa.gov/about/nasa-support-snwg/solutions/opera-north-america-disp-product)** across North America. Derived from Sentinel-1 Interferometric Wide (IW) acquisitions from **2016-07 to Present**, these products have a 6- to 12-day revisit frequency. The interactive tool allows users to define their region of interest by uploading a boundary shapefile or drawing a polygon directly on the map.
#
#
# **Reference**:
# 1. [Data set] NASA/JPL/OPERA. (2025). OPERA Surface Displacement from Sentinel-1 validated product (Version 1). NASA Alaska Satellite Facility Distributed Active Archive Center. https://doi.org/10.5067/SNWG/OPL3DISPS1-V1 Date Accessed: 2025-09-18
#
# ** **Note**: NASA is currently migrating all Earth science data sites to Earthdata, a process expected to continue through the end of 2026. During this transition, some NASA data and resources may not yet be accessible. This tool can automatically access new DISP-S1 products as they become available.
#
# ---
#
#
# Developed by **Qianjin Zheng**, **Adnan Rajib**, and **Dipen Saha**
#
# [Hydrology and Hydroinformatics Innovation (H2I) Lab](https://www.adnanrajib.com), University of Texas at Arlington

# %% [markdown]
# Please uncomment the following line each time before you run the tool for a new location (e.g., different watersheds or cities). This action will delete the entire output folder of your previous run.

# %% [markdown]
# ## Step 1: Environment Setup

# %%
# !wget https://raw.githubusercontent.com/OPERA-Cal-Val/OPERA_Applications/main/DISP/Discover/setup_env.py -O setup_env.py

import sys
import os

# Add current directory to sys.path
sys.path.append(os.getcwd())

from setup_env import install_dependencies
install_dependencies()
# Out:
# --2026-04-21 21:27:13--  https://raw.githubusercontent.com/OPERA-Cal-Val/OPERA_Applications/main/DISP/Discover/setup_env.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2313 (2.3K) [text/plain]
# Saving to: ‘setup_env.py’
#
# setup_env.py        100%[===================>]   2.26K  --.-KB/s    in 0s
#
# 2026-04-21 21:27:14 (16.1 MB/s) - ‘setup_env.py’ saved [2313/2313]
#
# All dependencies installed successfully.

# %%
# !{sys.executable} -m pip install \
    aiohttp requests fsspec \
    ipyleaflet gdown geopandas \
    rioxarray rasterio numcodecs zarr \
    matplotlib pandas pillow branca localtileserver mintpy
# Out:
# Requirement already satisfied: aiohttp in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (3.13.1)
# Requirement already satisfied: requests in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (2.32.5)
# Requirement already satisfied: fsspec in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (2025.9.0)
# Requirement already satisfied: ipyleaflet in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (0.20.0)
# Requirement already satisfied: gdown in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (5.2.0)
# Requirement already satisfied: geopandas in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: rioxarray in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (0.14.1)
# Requirement already satisfied: rasterio in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (1.4.3)
# Requirement already satisfied: numcodecs in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: zarr in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (2.12.0)
# Requirement already satisfied: matplotlib in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (3.10.7)
# Requirement already satisfied: pandas in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: pillow in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (12.0.0)
# Requirement already satisfied: branca in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (0.8.2)
# Requirement already satisfied: localtileserver in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (0.10.6)
# Requirement already satisfied: mintpy in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (1.6.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (1.22.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from multidict<7.0,>=4.5->aiohttp) (4.15.0)
# Requirement already satisfied: idna>=2.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from requests) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from requests) (2025.10.5)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipyleaflet) (8.1.7)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipyleaflet) (0.20.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipyleaflet) (0.2.1)
# Requirement already satisfied: xyzservices>=2021.8.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipyleaflet) (2025.4.0)
# Requirement already satisfied: comm>=0.1.3 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (8.37.0)
# Requirement already satisfied: traitlets>=4.3.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.15)
# Requirement already satisfied: beautifulsoup4 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from gdown) (4.14.2)
# Requirement already satisfied: filelock in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from gdown) (3.20.0)
# Requirement already satisfied: tqdm in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from gdown) (4.67.1)
# Requirement already satisfied: numpy>=1.24 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from geopandas) (2.2.6)
# Requirement already satisfied: pyogrio>=0.7.2 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from geopandas) (0.11.1)
# Requirement already satisfied: packaging in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from geopandas) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=2.0.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from geopandas) (2.1.2)
# Requirement already satisfied: xarray>=0.17 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from rioxarray) (2025.6.1)
# Requirement already satisfied: affine in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: click>=4.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from rasterio) (8.3.0)
# Requirement already satisfied: cligj>=0.5 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: click-plugins in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from rasterio) (1.1.1.2)
# Requirement already satisfied: pyparsing in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from rasterio) (3.2.5)
# Requirement already satisfied: asciitree in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from zarr) (0.3.3)
# Requirement already satisfied: fasteners in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from zarr) (0.20)
# Requirement already satisfied: contourpy>=1.0.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: python-dateutil>=2.7 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: jinja2>=3 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from branca) (3.1.6)
# Requirement already satisfied: flask<4,>=2.0.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from localtileserver) (3.1.2)
# Requirement already satisfied: Flask-Caching in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from localtileserver) (2.3.1)
# Requirement already satisfied: flask-cors in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from localtileserver) (6.0.1)
# Requirement already satisfied: flask-restx>=1.3.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from localtileserver) (1.3.2)
# Requirement already satisfied: rio-tiler in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from localtileserver) (7.9.2)
# Requirement already satisfied: rio-cogeo in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from localtileserver) (5.4.2)
# Requirement already satisfied: server-thread in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from localtileserver) (0.3.0)
# Requirement already satisfied: scooby in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from localtileserver) (0.10.2)
# Requirement already satisfied: werkzeug in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from localtileserver) (3.1.3)
# Requirement already satisfied: blinker>=1.9.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from flask<4,>=2.0.0->localtileserver) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from flask<4,>=2.0.0->localtileserver) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from flask<4,>=2.0.0->localtileserver) (3.0.3)
# Requirement already satisfied: pip in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (25.2)
# Requirement already satisfied: argcomplete in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (3.6.3)
# Requirement already satisfied: cartopy in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (0.25.0)
# Requirement already satisfied: cvxopt in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (1.3.2)
# Requirement already satisfied: dask>=1.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (2025.10.0)
# Requirement already satisfied: dask-jobqueue>=0.3 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (0.9.0)
# Requirement already satisfied: h5py in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (3.15.1)
# Requirement already satisfied: joblib in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (1.5.2)
# Requirement already satisfied: lxml in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (6.0.2)
# Requirement already satisfied: pyaps3>=0.3.6 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (0.3.7)
# Requirement already satisfied: pykml>=0.2 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (0.2.0)
# Requirement already satisfied: pyresample in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (1.31.0)
# Requirement already satisfied: pysolid in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (0.3.3)
# Requirement already satisfied: rich in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (14.2.0)
# Requirement already satisfied: scikit-image in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (0.25.2)
# Requirement already satisfied: scipy in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (1.15.3)
# Requirement already satisfied: utm in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from mintpy) (0.8.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from dask>=1.0->mintpy) (3.1.1)
# Requirement already satisfied: partd>=1.4.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from dask>=1.0->mintpy) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from dask>=1.0->mintpy) (6.0.3)
# Requirement already satisfied: toolz>=0.10.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from dask>=1.0->mintpy) (1.1.0)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from dask>=1.0->mintpy) (8.7.0)
# Requirement already satisfied: distributed>=2022.02.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from dask-jobqueue>=0.3->mintpy) (2025.10.0)
# Requirement already satisfied: locket>=1.0.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from distributed>=2022.02.0->dask-jobqueue>=0.3->mintpy) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from distributed>=2022.02.0->dask-jobqueue>=0.3->mintpy) (1.1.2)
# Requirement already satisfied: psutil>=5.8.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from distributed>=2022.02.0->dask-jobqueue>=0.3->mintpy) (7.1.1)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from distributed>=2022.02.0->dask-jobqueue>=0.3->mintpy) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from distributed>=2022.02.0->dask-jobqueue>=0.3->mintpy) (3.1.0)
# Requirement already satisfied: tornado>=6.2.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from distributed>=2022.02.0->dask-jobqueue>=0.3->mintpy) (6.5.2)
# Requirement already satisfied: zict>=3.0.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from distributed>=2022.02.0->dask-jobqueue>=0.3->mintpy) (3.0.0)
# Requirement already satisfied: aniso8601>=0.82 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from flask-restx>=1.3.0->localtileserver) (10.0.1)
# Requirement already satisfied: jsonschema in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from flask-restx>=1.3.0->localtileserver) (4.25.1)
# Requirement already satisfied: referencing in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from flask-restx>=1.3.0->localtileserver) (0.37.0)
# Requirement already satisfied: importlib-resources in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from flask-restx>=1.3.0->localtileserver) (6.5.2)
# Requirement already satisfied: zipp>=3.20 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from importlib_metadata>=4.13.0->dask>=1.0->mintpy) (3.23.0)
# Requirement already satisfied: decorator in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (5.2.1)
# Requirement already satisfied: exceptiongroup in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.19.2)
# Requirement already satisfied: stack_data in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.6.3)
# Requirement already satisfied: wcwidth in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.0)
# Requirement already satisfied: cdsapi>=0.7.2 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from pyaps3>=0.3.6->mintpy) (0.7.7)
# Requirement already satisfied: pygrib in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from pyaps3>=0.3.6->mintpy) (2.1.6)
# Requirement already satisfied: ecmwf-datastores-client>=0.4.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from cdsapi>=0.7.2->pyaps3>=0.3.6->mintpy) (0.4.0)
# Requirement already satisfied: multiurl>=0.3.7 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from ecmwf-datastores-client>=0.4.0->cdsapi>=0.7.2->pyaps3>=0.3.6->mintpy) (0.3.7)
# Requirement already satisfied: six>=1.5 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: pyshp>=2.3 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from cartopy->mintpy) (3.0.2.post1)
# Requirement already satisfied: cachelib>=0.9.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from Flask-Caching->localtileserver) (0.13.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from jsonschema->flask-restx>=1.3.0->localtileserver) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from jsonschema->flask-restx>=1.3.0->localtileserver) (0.27.1)
# Requirement already satisfied: configobj in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from pyresample->mintpy) (5.0.9)
# Requirement already satisfied: pykdtree>=1.3.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from pyresample->mintpy) (1.4.3)
# Requirement already satisfied: donfig in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from pyresample->mintpy) (0.8.1.post1)
# Requirement already satisfied: platformdirs in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from pyresample->mintpy) (4.5.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from rich->mintpy) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->mintpy) (0.1.2)
# Requirement already satisfied: morecantile<7.0,>=5.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from rio-cogeo->localtileserver) (6.2.0)
# Requirement already satisfied: pydantic~=2.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from rio-cogeo->localtileserver) (2.12.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from pydantic~=2.0->rio-cogeo->localtileserver) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from pydantic~=2.0->rio-cogeo->localtileserver) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from pydantic~=2.0->rio-cogeo->localtileserver) (0.4.2)
# Requirement already satisfied: cachetools in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from rio-tiler->localtileserver) (6.2.1)
# Requirement already satisfied: color-operations in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from rio-tiler->localtileserver) (0.2.0)
# Requirement already satisfied: httpx in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from rio-tiler->localtileserver) (0.28.1)
# Requirement already satisfied: numexpr in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from rio-tiler->localtileserver) (2.14.1)
# Requirement already satisfied: pystac<2.0,>=1.9 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from rio-tiler->localtileserver) (1.14.1)
# Requirement already satisfied: anyio in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from httpx->rio-tiler->localtileserver) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from httpx->rio-tiler->localtileserver) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from httpcore==1.*->httpx->rio-tiler->localtileserver) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from anyio->httpx->rio-tiler->localtileserver) (1.3.1)
# Requirement already satisfied: networkx>=3.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from scikit-image->mintpy) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from scikit-image->mintpy) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from scikit-image->mintpy) (2025.5.10)
# Requirement already satisfied: lazy-loader>=0.4 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from scikit-image->mintpy) (0.4)
# Requirement already satisfied: uvicorn in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from server-thread->localtileserver) (0.38.0)
# Requirement already satisfied: executing>=1.2.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.0)
# Requirement already satisfied: pure-eval in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.3)

# %%
# !{sys.executable} -m pip install \
    aiohttp requests fsspec h5py s3fs botocore boto3
# Out:
# Requirement already satisfied: aiohttp in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (3.13.1)
# Requirement already satisfied: requests in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (2.32.5)
# Requirement already satisfied: fsspec in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (2025.9.0)
# Requirement already satisfied: h5py in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (3.15.1)
# Requirement already satisfied: s3fs in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (2025.9.0)
# Requirement already satisfied: botocore in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (1.40.49)
# Requirement already satisfied: boto3 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (1.40.49)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiohttp) (1.22.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from multidict<7.0,>=4.5->aiohttp) (4.15.0)
# Requirement already satisfied: idna>=2.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from requests) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from requests) (2025.10.5)
# Requirement already satisfied: numpy>=1.21.2 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from h5py) (2.2.6)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from s3fs) (2.25.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.12.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.17.3)
# Requirement already satisfied: six>=1.5 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.17.0)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from boto3) (0.14.0)

# %%
# !{sys.executable} -m pip install h5netcdf netCDF4
# Out:
# Requirement already satisfied: h5netcdf in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (1.7.3)
# Requirement already satisfied: netCDF4 in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (1.7.3)
# Requirement already satisfied: h5py in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from h5netcdf) (3.15.1)
# Requirement already satisfied: packaging in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from h5netcdf) (25.0)
# Requirement already satisfied: cftime in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from netCDF4) (1.6.5)
# Requirement already satisfied: certifi in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from netCDF4) (2025.10.5)
# Requirement already satisfied: numpy in /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages (from netCDF4) (2.2.6)

# %%
from numcodecs import Blosc
import zarr.codecs
zarr.codecs.BloscCodec = Blosc

import requests, folium, json, os, glob, matplotlib, gdown, gc, shutil, h5py, pyproj, textwrap, base64, warnings
import geopandas as gpd
import pandas as pd
from ipyleaflet import Map, basemaps, basemap_to_tiles, DrawControl, ImageOverlay, LayersControl
from getpass import getpass
from io import BytesIO
from netrc import netrc, NetrcParseError
from platform import system
from disp_xr import (download, static_layers, product, stack as disp_stack, quality_metrics, io)
from opera_utils.disp._search import search
from datetime import datetime, timezone
import xarray as xr
from pyproj import CRS, Transformer
from rasterio.crs import CRS
from pathlib import Path
from typing import Any, Dict, NamedTuple, Tuple, Union, Optional
from mintpy.utils import utils as ut
from concurrent.futures import ThreadPoolExecutor, as_completed
import rioxarray as rxr
import rasterio as rasterio
from matplotlib import cm, colorbar, ticker
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import branca.colormap as cm
from localtileserver import get_leaflet_tile_layer, TileClient
from rasterio.warp import calculate_default_transform, reproject, Resampling
# from rich import print
from rich.panel import Panel
from branca.element import Element

warnings.filterwarnings("ignore")
# Out:
# /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages/localtileserver/_version.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %% [markdown]
# ## Step 2: Define functions

# %%
def write_netrc():
    username = getpass(prompt=prompts[0])
    password = getpass(prompt=prompts[1])
    with open(netrc_path, 'w') as f:
        f.write(f"\nmachine {urs}\n")
        f.write(f"login {username}\n")
        f.write(f"password {password}\n")
    os.chmod(netrc_path, 0o600)

def has_urs_credentials():
    try:
        creds = netrc(netrc_path).authenticators(urs)
        return creds is not None
    except (FileNotFoundError, NetrcParseError):
        return False

# %%
def clear_m():
    global rects,polys
    rects = set()
    polys = set()

def handle_draw(self, action, geo_json):
    global rects,polys
    polygon=[]
    for coords in geo_json['geometry']['coordinates'][0][:-1][:]:
        polygon.append(tuple(coords))
    polygon = tuple(polygon)
    if geo_json['properties']['style']['color'] == '#0096FF':  # poly
        if action == 'created':
            polys.add(polygon)
        elif action == 'deleted':
            polys.discard(polygon)
    if geo_json['properties']['style']['color'] == '#0096FF':  # rect
        if action == 'created':
            rects.add(polygon)
        elif action == 'deleted':
            rects.discard(polygon)

def save_drawn_aoi(draw_control, out_dir):
  drawn_feature = draw_control.last_draw['geometry']
  if drawn_feature is not None:
    with open(out_dir+'/boundary.json', 'w') as stream:
      json.dump(draw_control.last_draw, stream, indent=2)
    gdf = gpd.read_file(out_dir+'/boundary.json')
    gdf.to_file(out_dir+'/boundary.shp')
    aoi = out_dir+'/boundary.shp'

  else: print("Please draw a Polygon feature.")
  return aoi

# %%
def print_boxed_message(message, title="", padding=1, bold_title=True):

    lines = message.split("\n")
    max_len = max([len(line) for line in lines] + [len(title)])
    if title:
        if bold_title:
            title_text = f"\033[1;31m{title}\033[0m"
        else:
            title_text = title
        max_len = max(max_len, len(title))

    if title:
        print(title_text.ljust(max_len))
    print("*" * (max_len + 4))
    for _ in range(padding):
        print("*" + " " * (max_len + 2) + "*")
    for line in lines:
        print("* " + line.ljust(max_len) + " *")
    for _ in range(padding):
        print("*" + " " * (max_len + 2) + "*")
    print("*" * (max_len + 4))

# %%
def decode_metadata_time(v):
    if isinstance(v, (np.ndarray, bytes)):
        return b"".join(v).decode("utf-8") if isinstance(v[0], (bytes, np.bytes_)) else str(v)
    return str(v)

def extract_pixel_bbox_from_lalo(coord, lonlat_bbox):
    min_lon,  max_lon, min_lat, max_lat = lonlat_bbox.values()
    y0, x0 = coord.lalo2yx(min_lat, min_lon)
    y1, x1 = coord.lalo2yx(max_lat, max_lon)
    return slice(int(min(y0, y1)), int(max(y0, y1))), slice(int(min(x0, x1)), int(max(x0, x1)))

def get_metadata(disp_nc: str | Path | BytesIO| h5py.File, reference_date: Optional[str] = None) -> dict:
    """Get metadata for MINTPY from a DISP NetCDF file.

    Args:
        disp_nc (str or Path): The path to the DISP NetCDF file.
        reference_date (str, optional): The reference date. Defaults to None.

    Returns:
        dict: A dictionary containing the metadata.

    """
    # Get high-level metadata from DISP
    is_open_file = isinstance(disp_nc, h5py.File)
    if is_open_file:
        ds = disp_nc
    else:
        ds = h5py.File(disp_nc, "r")
    length, width = ds["displacement"][:].shape

    # Get general metadata
    metadata = {}
    for key, value in ds.attrs.items():
        metadata[key] = value

    for key, value in ds["identification"].items():
        value = value[()]
        if isinstance(value, (bytes, bytearray)):
            value = value.decode("utf-8")
        metadata[key] = value

    for key, value in ds["metadata"].items():
        # Skip unnecessary keys
        if key not in ["reference_orbit", "secondary_orbit", "processing_information"]:
            metadata[key] = value[()]

    metadata["x"] = ds["x"][:]
    metadata["y"] = ds["y"][:]
    metadata["length"] = length
    metadata["width"] = width
    ds.close()
    del ds

    # Get geospatial information
    geo_info = io.get_geospatial_info(disp_nc)

    ## Prepare it in mintpy atr format
    metadata["LENGTH"] = geo_info.rows
    metadata["WIDTH"] = geo_info.cols

    metadata["X_FIRST"] = geo_info.gt[0]
    metadata["Y_FIRST"] = geo_info.gt[3]
    metadata["X_STEP"] = geo_info.gt[1]
    metadata["Y_STEP"] = geo_info.gt[5]
    metadata["GT"] = geo_info.transform
    metadata["X_UNIT"] = metadata["Y_UNIT"] = "meters"
    metadata["WAVELENGTH"] = metadata["radar_wavelength"]
    metadata["REF_DATE"] = reference_date

    # Projection and UTM zone
    proj = CRS.from_wkt(geo_info.crs.wkt)
    epsg_code = proj.to_epsg()
    if str(epsg_code).startswith("326"):
        metadata["UTM_ZONE"] = str(epsg_code)[3:] + "N"
    elif str(epsg_code).startswith("327"):
        metadata["UTM_ZONE"] = str(epsg_code)[3:] + "S"
    else:
        metadata["UTM_ZONE"] = "UNKNOWN"
    metadata["EPSG"] = epsg_code

    # Hardcoded values
    metadata["ALOOKS"] = metadata["RLOOkS"] = 1
    metadata["EARTH_RADIUS"] = 6371000.0  # Hardcoded
    metadata["FILE_TYPE"] = "timeseries"
    metadata["UNIT"] = "m"
    metadata["AZIMUTH_PIXEL_SIZE"] = 14.1  # where this comes from

    # Datetime
    try:
      t = pd.to_datetime([metadata["reference_zero_doppler_start_time"], metadata["reference_zero_doppler_end_time"],])
    except:
      start_time = decode_metadata_time(metadata["reference_zero_doppler_start_time"])
      end_time = decode_metadata_time(metadata["reference_zero_doppler_end_time"])

      # Convert to datetime
      t = pd.to_datetime([start_time, end_time])
    t_mid = t[0] + t.diff()[1] / 2
    total_seconds = (t_mid.hour * 3600 + t_mid.minute * 60 + t_mid.second + t_mid.microsecond / 1e6)
    metadata["CENTER_LINE_UTC"] = total_seconds

    # Clean up of metadata dicts
    try:
      for key in ["reference_datetime", "secondary_datetime"]:
         del metadata[key]
    except:
      pass
    return metadata

# %%
def process_file(url, bbox, outdir, username, password):
    filename = url.split("/")[-1]
    base, ext = os.path.splitext(filename)
    outname = f"{outdir}/{base}.nc"

    if os.path.exists(outname):
        print(f"Skipped (exists): {filename}")
        return

    session = requests.Session()
    session.auth = (username, password)

    # Define compression settings
    comp = dict(zlib=True, complevel=4, shuffle=True)
    chunk_shape = (512, 512)

    try:
        with session.get(url, stream=True) as response:
            response.raise_for_status()
            file_bytes = BytesIO(response.content)

            try:
                with h5py.File(file_bytes, "r") as h5f:
                    def clip_bbox(ds, bbox):
                        height = ds.sizes["y"]
                        width = ds.sizes["x"]
                        x_start = max(0, min(width, bbox[0]))
                        x_stop = max(0, min(width, bbox[1]))
                        y_start = max(0, min(height, bbox[2]))
                        y_stop = max(0, min(height, bbox[3]))
                        if x_start >= x_stop or y_start >= y_stop:
                            return None
                        return (slice(y_start, y_stop), slice(x_start, x_stop))

                    if bbox is not None:
                        with xr.open_dataset(h5f, engine="h5netcdf") as ds:
                            clipped = clip_bbox(ds, bbox)
                            if clipped is None:
                                print(f"Skipped (bbox out of bounds): {filename}")
                                return
                            subset = ds.isel(y=clipped[0], x=clipped[1])
                            encoding = {
                                v: {**comp, "chunksizes": chunk_shape}
                                for v in subset.data_vars
                                if subset[v].dtype.kind in "fiu"
                            }
                            subset.to_netcdf(outname, engine="h5netcdf", encoding=encoding)

                        with xr.open_dataset(h5f, engine="h5netcdf", group="corrections") as ds_corr:
                            clipped = clip_bbox(ds_corr, bbox)
                            if clipped is not None:
                                corr_subset = ds_corr.isel(y=clipped[0], x=clipped[1])
                                encoding = {
                                    v: {**comp, "chunksizes": chunk_shape}
                                    for v in corr_subset.data_vars
                                    if corr_subset[v].dtype.kind in "fiu"
                                }
                                corr_subset.to_netcdf(outname, mode="a", group="corrections", engine="h5netcdf", encoding=encoding)
                    else:
                        with xr.open_dataset(h5f, engine="h5netcdf") as ds:
                            encoding = {
                                v: {**comp, "chunksizes": chunk_shape}
                                for v in ds.data_vars
                                if ds[v].dtype.kind in "fiu"
                            }
                            ds.to_netcdf(outname, engine="h5netcdf", encoding=encoding)

                        with xr.open_dataset(h5f, engine="h5netcdf", group="corrections") as ds_corr:
                            encoding = {
                                v: {**comp, "chunksizes": chunk_shape}
                                for v in ds_corr.data_vars
                                if ds_corr[v].dtype.kind in "fiu"
                            }
                            ds_corr.to_netcdf(outname, mode="a", group="corrections", engine="h5netcdf", encoding=encoding)

                    # Copy full metadata groups without subsetting or compression
                    for group in ["metadata", "identification"]:
                        try:
                            with h5py.File(outname, "a") as dest_hf:
                                if group in dest_hf:
                                    del dest_hf[group]
                                h5f.copy(group, dest_hf, name=group)
                        except Exception as e:
                            print(f"Failed to copy group '{group}': {e}")

                    copy_group_h5py(h5f, outname, "metadata/reference_orbit")
                    copy_group_h5py(h5f, outname, "metadata/secondary_orbit")

            finally:
                file_bytes.close()
                del file_bytes
                gc.collect()

    finally:
        session.close()

    print(f"Done: {filename}")


def copy_group_h5py(source_h5, target_path, group_name):
    try:
        with h5py.File(target_path, "a") as target_h5:
            src_group = source_h5[group_name]
            tgt_group = target_h5.require_group(group_name)

            for name, dataset in src_group.items():
                if name in tgt_group:
                    del tgt_group[name]
                tgt_ds = tgt_group.create_dataset(name, data=dataset[()])
                for key, val in dataset.attrs.items():
                    tgt_ds.attrs[key] = val

            for key, val in src_group.attrs.items():
                tgt_group.attrs[key] = val

    except Exception as e:
        print(f" Failed to copy {group_name} with h5py: {e}")

def download_disp_files(nc_urls, bbox, outdir, username, password, num_workers=3):
    """
    Download and optionally crop DISP NetCDF files in parallel.

    Args:
        nc_urls (list): List of DISP file URLs.
        bbox (list or None): Pixel bounding box [col_start, col_end, row_start, row_end] or None for full frame.
        outdir (str or Path): Output directory for NetCDF files.
        username (str): Earthdata username.
        password (str): Earthdata password.
        num_workers (int): Number of parallel threads.
    """
    with ThreadPoolExecutor(max_workers=num_workers) as executor:
        future_to_url = {executor.submit(process_file, url, bbox, outdir, username, password): url for url in nc_urls}
        for future in as_completed(future_to_url):
            _ = future.result()

# %% [markdown]
# ## Step 3: Accessing Earthdata-Hosted Products
#
# 1. Before starting this step, make sure you have a NASA Earthdata account set up in [NASA's Earthdata system](https://urs.earthdata.nasa.gov/).
# 2. Next, check if your account has authorized apps for ***Alaska Satellite Facility data access***.
# 3. If it does not, follow these steps:
#     *   Go to the Earthdata website and log in.
#     *   In the menu, select **Applications**, then click **Authorized Apps**.
#     *   Click **Approve More Applications**.
#     *   Select **Alaska Satellite Facility Data Access** and click **Authorize**.
#     *   A prompt with an agreement will appear. Check the box and click **Agree**.
# 4. Run the following cell. When prompted, enter your NASA Earthdata username, press Enter, then enter your password and press Enter again.
# 5. If you make a mistake or if the following cells show download errors, rerun this cell and ensure the credentials are entered correctly.

# %%
urs = 'urs.earthdata.nasa.gov'
prompts = ['Enter NASA Earthdata Login Username: ',
           'Enter NASA Earthdata Login Password: ']

netrc_name = "_netrc" if system() == "Windows" else ".netrc"
netrc_path = os.path.expanduser(f"~/{netrc_name}")

if not has_urs_credentials():
    if not os.path.exists(netrc_path):
        open(netrc_path, 'w').close()
    write_netrc()

username, _, password = netrc(str(netrc_path)).authenticators("urs.earthdata.nasa.gov")

# %% [markdown]
# ## Step 4: Select your location of interest

# %% [markdown]
# In this section, please draw and specify your location of interest by following these steps:
#
# 1.   After running the code, navigate the map and zoom in to your desired location.
# 2.   Next, click on **"Draw a polygon"** OR **"Draw a rectangle"** on the left panel of the map.
# 3.   Finally, move your cursor to the desired location and draw rectangle or polygon on the map.
#
#
# *Tip*: You can redraw the box by clicking the trash icon, selecting Clear All, and starting over.
#
# *Note*: Only the last bounding box drawn will be used for the analysis.

# %%
out_dir = "Tools/SubsidanceProject"
os.makedirs(out_dir, exist_ok=True)
results_path = out_dir+'/OPERA_L3_DISP-S1'
os.makedirs(results_path, exist_ok=True)

url = "https://raw.githubusercontent.com/OPERA-Cal-Val/OPERA_Applications/refs/heads/main/DISP/Discover/Frames_Information.geojson"
response = requests.get(url)
with open(out_dir+"/frames_info.geojson", "wb") as f:
    f.write(response.content)

file_id = "1ofDELiGuupym5_n8KLfPPG-n5kTnH3pw"
url = f"https://drive.google.com/uc?id={file_id}"
output = out_dir+"/VLM_IDW_clipped.tif"
gdown.download(url, output, quiet=False)

dst_path = out_dir+"/VLM_IDW_webmerc.tif"
dst_crs = "EPSG:3857"
with rasterio.open(output) as src:
    transform, width, height = calculate_default_transform(src.crs, dst_crs, src.width, src.height, *src.bounds)
    kwargs = src.meta.copy()
    kwargs.update({"crs": dst_crs,"transform": transform,"width": width,"height": height})
    with rasterio.open(dst_path, "w", **kwargs) as dst:
        for i in range(1, src.count + 1):
            reproject(source=rasterio.band(src, i),destination=rasterio.band(dst, i),src_transform=src.transform,
                      src_crs=src.crs,dst_transform=transform,dst_crs=dst_crs,resampling=Resampling.nearest)

client = TileClient(out_dir+"/VLM_IDW_webmerc.tif")
vlm_layer = get_leaflet_tile_layer(client,name="VLM (IDW)",opacity=0.5,colormap="viridis")

m = Map(center=client.center(),basemap=basemaps.Esri.WorldTopoMap,zoom=6, max_bounds=True)
m.add_layer(vlm_layer)
m.add_control(LayersControl(position='topright'))

clear_m()
draw_control = DrawControl(marker={}, circle={}, circlemarker={}, polyline={},
                           polygon={'shapeOptions':{'color':'#0096FF'}},rectangle={'shapeOptions':{'color':'#0096FF'}})
draw_control.on_draw(handle_draw)
m.add(draw_control)

display(m)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ofDELiGuupym5_n8KLfPPG-n5kTnH3pw
# To: /scratch/11097/shihab_h2i_uta/tapis/3daa08c5-c94c-4918-873b-ebd2b8a3d34d-007/work/cookbooks/cookbook-h2iUTA-jupyter-20251216111649/Tools/Tools/SubsidanceProject/VLM_IDW_clipped.tif
# 100%|██████████| 2.52M/2.52M [00:00<00:00, 48.9MB/s]
# Map(center=[31.172366, -100.0773605], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_titl…

# %%
geojson_gdf = gpd.read_file(out_dir+"/frames_info.geojson")
shapefile_gdf = gpd.read_file(save_drawn_aoi(draw_control, out_dir))
bbox_bounds = {}
BBOX2 = shapefile_gdf.bounds
row = BBOX2.iloc[0]
bbox_bounds.update({"lon_min": float(row["minx"]),"lon_max": float(row["maxx"]),"lat_min": float(row["miny"]),"lat_max": float(row["maxy"])})

if geojson_gdf.crs != shapefile_gdf.crs:
    shapefile_gdf = shapefile_gdf.to_crs(geojson_gdf.crs)

utm_crs = "EPSG:32614"
geojson_gdf_pro = geojson_gdf.to_crs(utm_crs)
shapefile_gdf_pro = shapefile_gdf.to_crs(utm_crs)
intersections = gpd.overlay(geojson_gdf_pro, shapefile_gdf_pro, how="intersection")
intersections["intersect_area"] = intersections.geometry.area
intersections["bound_area"] = shapefile_gdf_pro.geometry.area.iloc[0]
intersections["overlap_ratio"] = (intersections["intersect_area"] / intersections["bound_area"]) * 100

lst = []
for id in intersections["Frame ID"].tolist():
  df = search(frame_id=id)
  if len(df) == 0:
    lst.append(id)
intersections = intersections[~intersections["Frame ID"].isin(lst)]

message = []
if len(intersections) == 0:
  message.append("No satellite data is available for the selected location currently.\n"
  "\033[1mPlease re-run the code above and select a different area.\033[0m")
else:
  filtered = intersections[intersections["overlap_ratio"] > 50]
  if len(filtered) > 0:
    id_list = filtered["Frame ID"].tolist()
    message.append("Coverage is sufficient."
    "Please select the time range for the dataset using the steps below.")
  else:
    id_list = intersections["Frame ID"].tolist()
    message.append("The selected location is covered by satellite data for less than 50% of its area.\n"
    "If you wish to select a different location, please rerun the code above;\n"
    "otherwise, you may continue with the current selection.")

  products_df = pd.concat([download.search(frame_id=fid) for fid in id_list], ignore_index=True)
  min_date, max_date = products_df["reference_datetime"].min().date(), products_df["secondary_datetime"].max().date()

  message.append(" \n"
                 f"Select DISP-S1 time range for your selected location. \n"
                 f"\033[1mTotal coverage: {min_date} to {max_date}\033[0m")

print_boxed_message(" ".join(message), title="Messages", padding=1, bold_title=True)
# Out:
# Messages
# ************************************************************************************************
# *                                                                                              *
# * Coverage is sufficient.Please select the time range for the dataset using the steps below.   *
# * Select DISP-S1 time range for your selected location.                                        *
# * Total coverage: 2016-07-03 to 2025-09-26                                             *
# *                                                                                              *
# ************************************************************************************************

# %% [markdown]
# ## Step 5: Select time range for DISP-S1 product

# %%
while True:
    start_date = input("Enter the start date (YYYY-MM-DD): ")
    end_date = input("Enter the end date (YYYY-MM-DD): ")

    try:
        start_datetime = datetime.strptime(start_date, "%Y-%m-%d").replace(tzinfo=timezone.utc)
        end_datetime = datetime.strptime(end_date, "%Y-%m-%d").replace(tzinfo=timezone.utc)
    except ValueError:
        print("Invalid date format. Please use YYYY-MM-DD.")
        continue

    # Filter the dataframe
    filtered = products_df[(products_df["reference_datetime"] >= start_datetime) & (products_df["secondary_datetime"] <= end_datetime)]

    if filtered.empty:
      print("\033[1;31mMessage: \033[0m")
      print("**************************************************")
      print("No DISP-S1 data available for this date range. \n"
      "Please enter another range.")
      print("**************************************************")

    else:
      nc_urls = [line.strip() for line in filtered['filename'].values if isinstance(line, str) and line.strip()]
      print("\033[1;31mMessage: \033[0m")
      print("*******************************************************************************************************************")
      print(f"Your selected area includes {len(id_list)} frame IDs.")
      print(f"Within this region, {filtered.shape[0]} DISP-S1 granules are available for download during the defined date range.")
      print("*******************************************************************************************************************")
      break
# Out:
# Enter the start date (YYYY-MM-DD):  2017-01-01
# Enter the end date (YYYY-MM-DD):  2017-05-01
# Message:
# *******************************************************************************************************************
# Your selected area includes 1 frame IDs.
# Within this region, 3 DISP-S1 granules are available for download during the defined date range.
# *******************************************************************************************************************

# %% [markdown]
# ## Step 6: Estimate results size and download selected DISP-S1 data
#
# IMPORTANT:
# 1. This steps may take a few minutes depending on your settings and internet speed.
# 2. If the estimated download size is too large for your available storage (≈50 GB), consider reducing the bounding box and re-running the previous cells (e.g., credentials, search, bounding box).
# 3. If Colab disconnects or crashes, you’ll need to re-run the previous cells, but already downloaded files will remain available unless the runtime is fully reset.

# %%
session = requests.Session()
session.auth = (username, password)
response = session.get(nc_urls[0])
response.raise_for_status()
file_bytes = BytesIO(response.content)
file_size = file_bytes.getbuffer().nbytes / 1024**2 # in MB

meta = get_metadata(file_bytes)
coord = ut.coordinate(meta)
y_slice, x_slice = extract_pixel_bbox_from_lalo(coord, bbox_bounds)
row_start, row_end = y_slice.start, y_slice.stop
col_start, col_end = x_slice.start, x_slice.stop
pixel_bbox = [col_start, col_end, row_start, row_end]

# Estimate subset size
with xr.open_dataset(file_bytes, engine="h5netcdf") as ds:
    full_height, full_width = ds.sizes["y"], ds.sizes["x"]
    # Clip pixel bounds safely
    col_start = max(0, min(full_width, col_start))
    col_end = max(0, min(full_width, col_end))
    row_start = max(0, min(full_height, row_start))
    row_end = max(0, min(full_height, row_end))
    subset_height = row_end - row_start
    subset_width = col_end - col_start
    if subset_height == 0 or subset_width == 0:
        ratio = 0
        subset_file_size = 0
    else:
        ratio = (subset_height * subset_width) / (full_height * full_width)
        raw_nbytes = ds.nbytes
        actual_compression_ratio = (file_size * 1024**2) / raw_nbytes
        subset_file_size = (raw_nbytes * ratio * actual_compression_ratio) / 1024**2  # MB

stack_gb = (subset_file_size * len(nc_urls)) / 1024

print(f"Subset size: ~{subset_file_size:.2f} MB")
print(f"Estimated total stack size: {stack_gb:.2f} GB")
print("⚠️  Ensure you have enough space or reduce the crop area.")
# Out:
# Subset size: ~3.93 MB
# Estimated total stack size: 0.01 GB
# ⚠️  Ensure you have enough space or reduce the crop area.

# %%
session = requests.Session()
session.auth = (username, password)
response = session.get(nc_urls[0])
response.raise_for_status()
file_bytes = BytesIO(response.content)
file_size = file_bytes.getbuffer().nbytes / 1024**2 # in MB
meta = get_metadata(file_bytes)
coord = ut.coordinate(meta)
y_slice, x_slice = extract_pixel_bbox_from_lalo(coord, bbox_bounds)
row_start, row_end = y_slice.start, y_slice.stop
col_start, col_end = x_slice.start, x_slice.stop
pixel_bbox = [col_start, col_end, row_start, row_end]

download_disp_files(nc_urls, pixel_bbox, results_path, username, password, num_workers=2)
# Out:
# Done: OPERA_L3_DISP-S1_IW_F01097_VV_20170324T004314Z_20170405T004315Z_v1.0_20251024T055415Z.nc
# Done: OPERA_L3_DISP-S1_IW_F01097_VV_20170324T004314Z_20170429T004316Z_v1.0_20251024T055415Z.nc
# Done: OPERA_L3_DISP-S1_IW_F01097_VV_20170324T004314Z_20170417T004315Z_v1.0_20251024T055415Z.nc

# %% [markdown]
# ## Step 7: Explore and visualize a downloaded DISP-S1 Dataset

# %%
results_list = [file for file in glob.glob(results_path+"/*.nc")]
parts = results_list[-1].split('_')
part1 = parts[-4][:8]
part2 = parts[-3][:8]
data = rxr.open_rasterio(results_list[-1])
disp = data["displacement"].sel(band=1)

coords  = shapefile_gdf.to_crs(epsg='4326').total_bounds
bounds = [[coords[1], coords[0]], [coords[3], coords[2]]]
lat = (coords[1] + coords[3]) / 2
lon = (coords[0] + coords[2]) / 2

disp_values = disp.values.copy()
disp_values = np.nan_to_num(disp_values, nan=np.nan)
vmin, vmax = np.nanpercentile(disp_values, [2, 98])
disp_clipped = np.clip(disp_values, vmin, vmax)
disp_norm = (disp_clipped - vmin) / (vmax - vmin)
cmap = plt.get_cmap('viridis')
disp_rgba = cmap(disp_norm)
disp_rgba[..., 3] = np.where(np.isnan(disp_values), 0, 1)
disp_rgba_img = (disp_rgba * 255).astype(np.uint8)
if disp_rgba_img.ndim == 3 and disp_rgba_img.shape[0] == 4:
    disp_rgba_img = np.transpose(disp_rgba_img, (1, 2, 0))
img = Image.fromarray(disp_rgba_img, mode="RGBA")
img.save(out_dir+"/disp_overlay.png")

m = folium.Map([lat, lon],zoom_start=10,tiles="cartodb positron")
m.add_child(folium.raster_layers.ImageOverlay(image=out_dir+"/disp_overlay.png",bounds=bounds,colormap='viridis',
                                              opacity=1,interactive=True,overlay=True,name='OPERA DISP-S1'))
vmin, vmax = np.nanpercentile(disp_values, [2, 98])
norm = matplotlib.colors.Normalize(vmin=vmin, vmax=vmax)

fig, ax = plt.subplots(figsize=(0.6,3),dpi=200)
fig.subplots_adjust(right=0.5)
sm = plt.cm.ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])
cbar = fig.colorbar(sm, cax=ax)
cbar.set_label("Displacement (m)", fontsize=9)

buf_leg = io.BytesIO()
fig.savefig(buf_leg, format="png", bbox_inches="tight")
plt.close(fig)
url = "data:image/png;base64," + base64.b64encode(buf_leg.getvalue()).decode("utf-8")

legend_html = f"""
<div style="
  position: fixed; bottom: 10px; left: 10px; z-index: 9999;
  background: #fff; border: 1px solid #999; border-radius: 6px;
  padding: 10px 12px; box-shadow: 0 1px 4px rgba(0,0,0,0.3);
  font-size: 12px; line-height: 1.2; pointer-events: none;">

  <!-- centered title -->
  <div style="width:100%; text-align:center; font-weight:700;">OPERA DISP-S1</div>
  <div style="width:100%; text-align:center; margin-bottom:6px;">Displacement (m)</div>

  <!-- colorbar row -->
  <div style="display:flex; align-items:center; gap:8px; justify-content:center;">
    <span style="min-width:42px; text-align:right;">{vmin:.2f}</span>
    <div style="
      height:14px; width:240px; border:1px solid #999; border-radius:3px;
      background: linear-gradient(to right,#440154,#482878,#3e4989,#31688e,#26828e,#1f9e89,#35b779,#6ece58,#b5de2b,#fde725);">
    </div>
    <span style="min-width:42px; text-align:left;">{vmax:.2f}</span>
  </div>
</div>
"""

m.get_root().html.add_child(Element(legend_html))

folium.LayerControl(collapsed=False).add_to(m)
display(m)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages/xarray/backends/file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<function open at 0x14f5809c0c10>, ('Tools/SubsidanceProject/OPERA_L3_DISP-S1/OPERA_L3_DISP-S1_IW_F28482_VV_20170223T003436Z_20170424T003438Z_v1.0_20251024T060430Z.nc',), 'r', (('sharing', False),), '9f684aa5-95ea-4c9e-a0fe-0241b77a3235']
#
# During handling of the above exception, another exception occurred:
#
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File rasterio/_base.pyx:310, in rasterio._base.DatasetBase.__init__()
#
# File rasterio/_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio/_err.pyx:359, in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: 'Tools/SubsidanceProject/OPERA_L3_DISP-S1/OPERA_L3_DISP-S1_IW_F28482_VV_20170223T003436Z_20170424T003438Z_v1.0_20251024T060430Z.nc' not recognized as being in a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# Cell In[34], line 5
#       3 part1 = parts[-4][:8]
#       4 part2 = parts[-3][:8]
# ----> 5 data = rxr.open_rasterio(results_list[-1])
#       6 disp = data["displacement"].sel(band=1)
#       8 coords  = shapefile_gdf.to_crs(epsg='4326').total_bounds
#
# File /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages/rioxarray/_io.py:1124, in open_rasterio(filename, parse_coordinates, chunks, cache, lock, masked, mask_and_scale, variable, group, default_name, decode_times, decode_timedelta, band_as_variable, **open_kwargs)
#    1122     else:
#    1123         manager = URIManager(file_opener, filename, mode="r", kwargs=open_kwargs)
# -> 1124     riods = manager.acquire()
#    1125     captured_warnings = rio_warnings.copy()
#    1127 # raise the NotGeoreferencedWarning if applicable
#
# File /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages/xarray/backends/file_manager.py:193, in CachingFileManager.acquire(self, needs_lock)
#     178 def acquire(self, needs_lock=True):
#     179     """Acquire a file object from the manager.
#     180
#     181     A new file is only opened if it has expired from the
#    (...)
#     191         An open file object, as returned by ``opener(*args, **kwargs)``.
#     192     """
# --> 193     file, _ = self._acquire_with_cache_info(needs_lock)
#     194     return file
#
# File /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages/xarray/backends/file_manager.py:217, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     215     kwargs = kwargs.copy()
#     216     kwargs["mode"] = self._mode
# --> 217 file = self._opener(*self._args, **kwargs)
#     218 if self._mode == "w":
#     219     # ensure file doesn't get overridden when opened again
#     220     self._mode = "a"
#
# File /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages/rasterio/env.py:463, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     460     session = DummySession()
#     462 with env_ctor(session=session):
# --> 463     return f(*args, **kwds)
#
# File /work/11097/shihab_h2i_uta/ls6/miniconda3/envs/shihab_clean/lib/python3.10/site-packages/rasterio/__init__.py:356, in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     353     path = _parse_path(raw_dataset_path)
#     355 if mode == "r":
# --> 356     dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     357 elif mode == "r+":
#     358     dataset = get_writer_for_path(path, driver=driver)(
#     359         path, mode, driver=driver, sharing=sharing, **kwargs
#     360     )
#
# File rasterio/_base.pyx:312, in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: 'Tools/SubsidanceProject/OPERA_L3_DISP-S1/OPERA_L3_DISP-S1_IW_F28482_VV_20170223T003436Z_20170424T003438Z_v1.0_20251024T060430Z.nc' not recognized as being in a supported file format.

# %%
m.save(results_path +"/Example_Map.html")

base_name = results_path
format = 'zip'
root_dir = out_dir
base_dir = "./%s"%(results_path.split('/')[-1])
shutil.make_archive(base_name,format,root_dir,base_dir)
# Out:
# '/scratch/11097/shihab_h2i_uta/tapis/ac97f4b9-30f7-4dd5-bc21-8aa81500bbdc-007/work/cookbooks/cookbook-h2iUTA-jupyter/Tools/Tools/SubsidanceProject/OPERA_L3_DISP-S1.zip'
